# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#参考" data-toc-modified-id="参考-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>参考</a></span></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#数据准备" data-toc-modified-id="数据准备-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数据准备</a></span></li><li><span><a href="#获取评分详情" data-toc-modified-id="获取评分详情-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>获取评分详情</a></span></li></ul></div>

# %% [markdown]
# ## 参考

# %% [markdown]
# https://www.scienjus.com/elasticsearch-function-score-query/

# %% [markdown]
# ## Setup

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from datetime import datetime
import pprint

# %%
es = Elasticsearch()

# %% [markdown]
# ## 数据准备

# %%
test_score_index = "test-index"

# %%
my_data_settting = {
    "settings": {
        "analysis": {
            "analyzer": {
                "my_analyzer": {
                    "tokenizer": "standard",
                    "char_filter": [
                        "my_char_filter"
                    ]
                } 
            },
            "char_filter": {
                "my_char_filter": {
                    "type": "mapping",
                    "mappings": [
                        "- => _hyphen_",
                    ]
                }
            }
        }
    },
    "mappings": {
        "my_type": {
            "properties": {
                "cmd_format_t": {
                    "type": "text",
                    "search_analyzer": "my_analyzer",
                    "analyzer": "my_analyzer",
                    "norms": { "enabled": False }
                }
            }
        }
    }
}

# %%
es.indices.delete(index=test_score_index)
es.indices.create(index=test_score_index, body=my_data_settting)
# Out:
# {'acknowledged': True}
# {'acknowledged': True, 'index': 'test-index', 'shards_acknowledged': True}

# %%
doc1 = {
    'author': 'tangting',
    'cmd_format_t': 'This is a brown dog a b',
    'len': 3,
    'cmd_format_min_len': 4,
    'cmd_format_max_len': 6
}
doc2 = {
    'author': 'tangting',
    'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
    'len': 3,
    'cmd_format_min_len': 4,
    'cmd_format_max_len': 8
}
doc3 = {
    'author': 'tangting',
    'cmd_format_t': 'This is a brown dog a b',
    'len': 3,
    'cmd_format_min_len': 4,
    'cmd_format_max_len': 10
} 
actions = [{ "_index": test_score_index, "_type": "my_type", "_id": idx, "_source": value} for idx, value in enumerate([doc1, doc2, doc3])]
helpers.bulk(es, actions)
# Out:
# (3, [])

# %%
es.search(index=test_score_index, body={"query": {"match_all": {}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '0',
#     '_index': 'test-index',
#     '_score': 1.0,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type'},
#    {'_id': '2',
#     '_index': 'test-index',
#     '_score': 1.0,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 15},
#     '_type': 'my_type'},
#    {'_id': '1',
#     '_index': 'test-index',
#     '_score': 1.0,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 4},
#     '_type': 'my_type'}],
#   'max_score': 1.0,
#   'total': 3},
#  'timed_out': False,
#  'took': 1}

# %% [markdown]
# ## 获取评分详情

# %%
es.search(index=test_score_index, explain=False, body={
    "query": {
        "match_phrase": {
            "cmd_format_t": {
                "query": "brown  a dog", "slop": 30
            }
        }
    },
    "highlight": {
        "fields" : {
            "cmd_format_t" : {}
        }
    }
})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '0',
#     '_index': 'test-index',
#     '_score': 0.6781078,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is <em>a</em> <em>brown</em> <em>dog</em> <em>a</em> b']}},
#    {'_id': '2',
#     '_index': 'test-index',
#     '_score': 0.6781078,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 5},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is <em>a</em> <em>brown</em> <em>dog</em> <em>a</em> b']}},
#    {'_id': '1',
#     '_index': 'test-index',
#     '_score': 0.6781078,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 4},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is <em>a</em> <em>brown</em> <em>dog</em> <em>a</em> asf sdfsdf s sdfsdfsdfsf  sdf s s s s s']}}],
#   'max_score': 0.6781078,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
es.search(index=test_score_index, explain=False, body={
    "query": {
        "function_score": {
            "query": {
                "match": {
                    "cmd_format_t": {
                        "query": "brown dog"
                    }
                }
            },
            "field_value_factor": {
                "field": "len",
                "modifier": "reciprocal",
                "factor": 0.9
            },
            "boost_mode": "multiply"
        }
    },
    "highlight": {
        "fields" : {
            "cmd_format_t" : {}
        }
    }
})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '0',
#     '_index': 'test-index',
#     '_score': 0.21309784,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}},
#    {'_id': '1',
#     '_index': 'test-index',
#     '_score': 0.15982339,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 4},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s']}},
#    {'_id': '2',
#     '_index': 'test-index',
#     '_score': 0.12785871,
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 5},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}}],
#   'max_score': 0.21309784,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
es.search(index=test_score_index, explain=True, body={
    "query": {
        "function_score": {
            "query": {
                "match": {
                    "cmd_format_t": {
                        "query": "brown dog"
                    }
                }
            },
            "gauss": {
                "len": { 
                    "origin": "3",  # 这里应该是输入的句子长度
                    "offset": "1",
                    "scale":  "20"
                }
            },
            "boost_mode": "multiply"
        }
    },
    "highlight": {
        "fields" : {
            "cmd_format_t" : {}
        }
    }
})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'sum of:',
#        'details': [{'description': 'weight(cmd_format_t:brown in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821},
#         {'description': 'weight(cmd_format_t:dog in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'Function for field len:',
#          'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(3.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#            'details': [],
#            'value': 1.0}],
#          'value': 1.0},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 1.0}],
#      'value': 0.5753642},
#     '_id': '0',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.5753642,
#     '_shard': '[test-index][0]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}},
#    {'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'sum of:',
#        'details': [{'description': 'weight(cmd_format_t:brown in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821},
#         {'description': 'weight(cmd_format_t:dog in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'Function for field len:',
#          'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(4.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#            'details': [],
#            'value': 1.0}],
#          'value': 1.0},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 1.0}],
#      'value': 0.5753642},
#     '_id': '1',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.5753642,
#     '_shard': '[test-index][3]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 4},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s']}},
#    {'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'sum of:',
#        'details': [{'description': 'weight(cmd_format_t:brown in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821},
#         {'description': 'weight(cmd_format_t:dog in 0) [PerFieldSimilarity], result of:',
#          'details': [{'description': 'score(doc=0,freq=1.0 = termFreq=1.0\n), product of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#              'details': [{'description': 'termFreq=1.0',
#                'details': [],
#                'value': 1.0},
#               {'description': 'parameter k1', 'details': [], 'value': 1.2},
#               {'description': 'parameter b (norms omitted for field)',
#                'details': [],
#                'value': 0.0}],
#              'value': 1.0}],
#            'value': 0.2876821}],
#          'value': 0.2876821}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'Function for field len:',
#          'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(15.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#            'details': [],
#            'value': 0.8108461}],
#          'value': 0.8108461},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 0.8108461}],
#      'value': 0.46653178},
#     '_id': '2',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.46653178,
#     '_shard': '[test-index][2]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 15},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}}],
#   'max_score': 0.5753642,
#   'total': 3},
#  'timed_out': False,
#  'took': 4}

# %%
es.search(index=test_score_index, explain=True, body={
    "query": {
        "function_score": {
            "query": {
                "match_phrase": {
                    "cmd_format_t": {
                        "query": "brown dog",
                        "slop": 30
                    }
                }
            },
            "functions": [
                {   
                    "field_value_factor": {
                        "field": "len",
                        "modifier": "reciprocal",
                        "factor": 0.9
                    }
                },
                {
                    "gauss": {
                        "len": { 
                            "origin": "3",  # 这里应该是输入的句子长度
                            "offset": "1",
                            "scale":  "20"
                        }
                    }
                }
            ],
            "score_mode": "multiply",
            "boost_mode": "multiply"
        }
    },
    "highlight": {
        "fields" : {
            "cmd_format_t" : {}
        }
    }
})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'weight(cmd_format_t:"brown dog"~30 in 0) [PerFieldSimilarity], result of:',
#        'details': [{'description': 'score(doc=0,freq=1.0 = phraseFreq=1.0\n), product of:',
#          'details': [{'description': 'idf(), sum of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821}],
#            'value': 0.5753642},
#           {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#            'details': [{'description': 'phraseFreq=1.0',
#              'details': [],
#              'value': 1.0},
#             {'description': 'parameter k1', 'details': [], 'value': 1.2},
#             {'description': 'parameter b (norms omitted for field)',
#              'details': [],
#              'value': 0.0}],
#            'value': 1.0}],
#          'value': 0.5753642}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'function score, score mode [multiply]',
#          'details': [{'description': "field value function: reciprocal(doc['len'].value * factor=0.9)",
#            'details': [],
#            'value': 0.3703704},
#           {'description': 'Function for field len:',
#            'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(3.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#              'details': [],
#              'value': 1.0}],
#            'value': 1.0}],
#          'value': 0.3703704},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 0.3703704}],
#      'value': 0.21309786},
#     '_id': '0',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.21309784,
#     '_shard': '[test-index][0]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}},
#    {'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'weight(cmd_format_t:"brown dog"~30 in 0) [PerFieldSimilarity], result of:',
#        'details': [{'description': 'score(doc=0,freq=1.0 = phraseFreq=1.0\n), product of:',
#          'details': [{'description': 'idf(), sum of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821}],
#            'value': 0.5753642},
#           {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#            'details': [{'description': 'phraseFreq=1.0',
#              'details': [],
#              'value': 1.0},
#             {'description': 'parameter k1', 'details': [], 'value': 1.2},
#             {'description': 'parameter b (norms omitted for field)',
#              'details': [],
#              'value': 0.0}],
#            'value': 1.0}],
#          'value': 0.5753642}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'function score, score mode [multiply]',
#          'details': [{'description': "field value function: reciprocal(doc['len'].value * factor=0.9)",
#            'details': [],
#            'value': 0.2777778},
#           {'description': 'Function for field len:',
#            'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(4.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#              'details': [],
#              'value': 1.0}],
#            'value': 1.0}],
#          'value': 0.2777778},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 0.2777778}],
#      'value': 0.15982339},
#     '_id': '1',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.15982339,
#     '_shard': '[test-index][3]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 4},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s']}},
#    {'_explanation': {'description': 'function score, product of:',
#      'details': [{'description': 'weight(cmd_format_t:"brown dog"~30 in 0) [PerFieldSimilarity], result of:',
#        'details': [{'description': 'score(doc=0,freq=1.0 = phraseFreq=1.0\n), product of:',
#          'details': [{'description': 'idf(), sum of:',
#            'details': [{'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821},
#             {'description': 'idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:',
#              'details': [{'description': 'docFreq',
#                'details': [],
#                'value': 1.0},
#               {'description': 'docCount', 'details': [], 'value': 1.0}],
#              'value': 0.2876821}],
#            'value': 0.5753642},
#           {'description': 'tfNorm, computed as (freq * (k1 + 1)) / (freq + k1) from:',
#            'details': [{'description': 'phraseFreq=1.0',
#              'details': [],
#              'value': 1.0},
#             {'description': 'parameter k1', 'details': [], 'value': 1.2},
#             {'description': 'parameter b (norms omitted for field)',
#              'details': [],
#              'value': 0.0}],
#            'value': 1.0}],
#          'value': 0.5753642}],
#        'value': 0.5753642},
#       {'description': 'min of:',
#        'details': [{'description': 'function score, score mode [multiply]',
#          'details': [{'description': "field value function: reciprocal(doc['len'].value * factor=0.9)",
#            'details': [],
#            'value': 0.074074075},
#           {'description': 'Function for field len:',
#            'details': [{'description': 'exp(-0.5*pow(MIN[Math.max(Math.abs(15.0(=doc value) - 3.0(=origin))) - 1.0(=offset), 0)],2.0)/288.5390081777927)',
#              'details': [],
#              'value': 0.8108461}],
#            'value': 0.8108461}],
#          'value': 0.060062677},
#         {'description': 'maxBoost', 'details': [], 'value': 3.4028235e+38}],
#        'value': 0.060062677}],
#      'value': 0.034557912},
#     '_id': '2',
#     '_index': 'test-index',
#     '_node': 'KQm9L7T2RMmbxHKzB29jdw',
#     '_score': 0.034557912,
#     '_shard': '[test-index][2]',
#     '_source': {'author': 'tangting',
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 15},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}}],
#   'max_score': 0.21309784,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
"return  1 / (Math.max((Math.abs(%s - %d) - 1), 0) + 1)" % ("doc['len'].value + doc['len'].value) / 2", target_len)
# Out:
# "return  1 / (Math.max((Math.abs(doc['len'].value + doc['len'].value) / 2 - 1) - 1), 0) + 1)"

# %%
target_len = 9
len_max = 'cmd_format_max_len'
len_min = 'cmd_format_min_len'
len_mid = "((doc['%s'].value + doc['%s'].value) / 2)" % (len_max, len_min)
len_offset = "((doc['%s'].value - doc['%s'].value) / 2)" % (len_max, len_min)
custom_script = "return  1 / (Math.max((Math.abs(%s - %d) - %s), 0) + 1)" % (
    len_mid, 
    target_len,
    len_offset
)

# custom_script = "return  1 / (Math.max((Math.abs(doc['len'].value  + doc['len'].value - %d) - 1), 0) + 1)" % (target_len)
es.search(index=test_score_index, explain=False, body={
    "query": {
        "function_score": {
            "query": {
                "match_phrase": {
                    "cmd_format_t": {
                        "query": "brown dog",
                        "slop": 30
                    }
                }
            },
            "functions": [
                {   
                    "field_value_factor": {
                        "field": "len",
                        "modifier": "reciprocal",
                        "factor": 0.9
                    }
                },
                {
                    "script_score": {
                        "script": custom_script
                    }
                }
            ],
            "score_mode": "multiply",
            "boost_mode": "multiply"
        }
    },
    "highlight": {
        "fields" : {
            "cmd_format_t" : {}
        }
    }
})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '2',
#     '_index': 'test-index',
#     '_score': 0.21309784,
#     '_source': {'author': 'tangting',
#      'cmd_format_max_len': 10,
#      'cmd_format_min_len': 4,
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}},
#    {'_id': '1',
#     '_index': 'test-index',
#     '_score': 0.10654892,
#     '_source': {'author': 'tangting',
#      'cmd_format_max_len': 8,
#      'cmd_format_min_len': 4,
#      'cmd_format_t': 'This is a brown dog a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a asf sdfsdf s sdfsdfsdfsf  sdf s s s s s']}},
#    {'_id': '0',
#     '_index': 'test-index',
#     '_score': 0.05327446,
#     '_source': {'author': 'tangting',
#      'cmd_format_max_len': 6,
#      'cmd_format_min_len': 4,
#      'cmd_format_t': 'This is a brown dog a b',
#      'len': 3},
#     '_type': 'my_type',
#     'highlight': {'cmd_format_t': ['This is a <em>brown</em> <em>dog</em> a b']}}],
#   'max_score': 0.21309784,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
0.3703704 * 0.3703704
# Out:
# 0.13717423319615998
