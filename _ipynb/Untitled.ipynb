# %%
1、Markdown语法

2、Github Pages + jekyll 使用

fork Minimal Mistakes[https://github.com/mmistakes/minimal-mistakes/fork]
修改repo名称为USERNAME.github.io，例如，jiexiao111.github.io
此时应该可以访问 https://jiexiao111.github.io/

安装 ruby
brew update
brew install ruby
重新打开iterm确保which ruby 的输出为 /usr/local/bin/ruby，否则修改~/.bash_profile添加环境变量
确认ruby -v 的输出大于2.1

安装 libxml2
brew install libxml2
重新打开iterm确保环境变量更新

cat > ~/.bundle/config
---
BUNDLE_BUILD__NOKOGIRI: --use-system-libraries --with-xml2-include=/usr/include/libxml2 --with-xml2-lib=/usr/lib/

clone fork 的 Minimal Mistakes
例如：git clone https://github.com/jiexiao111/jiexiao111.github.io.git

添加_config.yml至以下文件:
theme: minimal-mistakes-jekyll

拷贝以下内容至 Gemfile 文件，并执行 bundle install
gem "minimal-mistakes-jekyll"

拷贝以下内容至 Gemfile 文件，并执行 bundle update
source "https://rubygems.org"
gem "github-pages", group: :jekyll_plugins
group :jekyll_plugins do
  gem "jekyll-paginate"
  gem "jekyll-sitemap"
  gem "jekyll-gist"
  gem "jekyll-feed"
  gem "jemoji"
end

删除以下文件
rm .editorconfig
rm .gitattributes
rm .github
rm -rf docs
rm -rf tes  t
rm CHANGELOG.md
rm minimal-mistakes-jekyll.gemspec
rm README.md
rm screenshot-layouts.png
rm screenshot.pngrm

3、jupyter 使用

4、Minimal Mistakes 使用

5、Git 使用

6、IPython 使用

7、Tesorflow 使用

8、pandas 使用

9、numpy 使用

10、scipy 使用

11、kera 使用

12、python 使用

13、matplotlab 使用

14、jekyll 使用
